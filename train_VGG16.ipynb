# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -x /content/drive/MyDrive/fire/fire.zip -d /content/fire
# Out:
# Archive:  /content/drive/MyDrive/fire/fire.zip
#    creating: /content/fire/fire/
#    creating: /content/fire/fire/train/
#    creating: /content/fire/fire/train/Fire/
#   inflating: /content/fire/fire/train/Fire/fire10.jpg
#   inflating: /content/fire/fire/train/Fire/fire1000.jpg
#   inflating: /content/fire/fire/train/Fire/fire1001.jpg
#   inflating: /content/fire/fire/train/Fire/fire1002.jpg
#   inflating: /content/fire/fire/train/Fire/fire1003.jpg
#   inflating: /content/fire/fire/train/Fire/fire1004.jpg
#   inflating: /content/fire/fire/train/Fire/fire1005.jpg
#   inflating: /content/fire/fire/train/Fire/fire1006.jpg
#   inflating: /content/fire/fire/train/Fire/fire1007.jpg
#   inflating: /content/fire/fire/train/Fire/fire1008.jpg
#   inflating: /content/fire/fire/train/Fire/fire1009.jpg
#   inflating: /content/fire/fire/train/Fire/fire1010.jpg
#   inflating: /content/fire/fire/train/Fire/fire1011.jpg
#   inflating: /content/fire/fire/train/Fire/fire1012.jpg
# ...

# %%
import torchvision
from torchvision.models import vgg16, VGG16_Weights
model = vgg16(weights=VGG16_Weights.IMAGENET1K_V1)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:04<00:00, 128MB/s]

# %%
# !cp /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth /content/VGG16-from-scratch-Pytorch/vgg16-397923af.pth

# %%
# !git clone https://github.com/ChaosAIVision/VGG16-from-scratch-Pytorch.git
# Out:
# Cloning into 'VGG16-from-scratch-Pytorch'...
# remote: Enumerating objects: 133, done.
# remote: Counting objects: 100% (133/133), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 133 (delta 55), reused 99 (delta 24), pack-reused 0
# Receiving objects: 100% (133/133), 63.85 KiB | 4.56 MiB/s, done.
# Resolving deltas: 100% (55/55), done.

# %%
# !pip install pyyaml

# %%
# train: /content/fire/fire/train
# valid: /content/fire/fire/valid
# test:  /content/fire/fire/train
# num_classes: 2
# categories: ['Fire', 'NoFire']
# pretrain_weight: /content/VGG16-from-scratch-Pytorch/vgg16-397923af.pth
# save_dirs: /content/drive/MyDrive/fire

# %%
# %cd /content/VGG16-from-scratch-Pytorch
# !python train.py -d /content/VGG16-from-scratch-Pytorch/data.yaml -b 16 -e 100
# Out:
# /content/VGG16-from-scratch-Pytorch
# 2024-08-04 07:14:17.832746: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-04 07:14:17.852056: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-04 07:14:17.858043: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-04 07:14:17.872572: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...
